# %%
import numpy as np
import pandas as pd
from scipy.optimize import minimize

# ========= 1) Excel 读列 =========
file_path = r"your_data.xlsx"
sheet_name = "NLP"
# 非线性模型通常数据/参数从Excel读取后进入 obj_func
df = pd.read_excel(file_path, sheet_name=sheet_name)

# ========= 2) 参数模板 =========
params = {
    "x0": np.array([1.0, 1.0]),          # 初始点
    "bounds": ((0, 10), (0, 10)),        # 变量边界
}

def obj_func(x):
    """目标函数（你按题目改）"""
    return (x[0]-2)**2 + (x[1]-3)**2

res = minimize(obj_func, x0=params["x0"], method="SLSQP", bounds=params["bounds"], constraints=())
print(res.x, res.fun)

# %%
"""
非线性规划模型

使用方法：
1. 按照下方 TODO 修改 DATA_FILE、列名、参数和输出文件名。
2. 将数据文件放在本脚本同目录，或把 DATA_FILE 改成绝对路径。
3. 运行：python "非线性规划模型.py"
"""

from pathlib import Path
import numpy as np
import pandas as pd
from scipy.optimize import minimize



DATA_FILE = "data.csv"  # TODO: 请填写[数据文件路径]，说明：CSV/Excel 均可；若使用 Excel，请在 load_data 中改为 read_excel。
OUTPUT_FILE = "model_output.csv"  # TODO: 请填写[输出文件名]，说明：保存模型结果，建议保留 .csv 或 .xlsx 后缀。
RANDOM_STATE = 42  # TODO: 请填写[随机种子]，说明：用于复现实验；整数即可。
INITIAL_X = [0.5, 0.5]  # TODO: 请填写[初始解]，说明：长度等于变量数，对局部最优影响较大。
BOUNDS = [(0, None), (0, None)]  # TODO: 请填写[变量边界]，说明：无界可填 (None, None)。



REQUIRES_DATA = False  # 参数型模型可不提供数据文件；表格型模型必须提供数据。


def load_data() -> pd.DataFrame:
    """读取用户数据；竞赛时通常把 Excel/CSV 表格整理成一行一个样本。"""
    path = Path(DATA_FILE)
    if not path.exists():
        if not REQUIRES_DATA:
            return pd.DataFrame()
        raise FileNotFoundError(
            f"未找到数据文件 {DATA_FILE}。请先修改 DATA_FILE，或将数据放到脚本同目录。"
        )
    if path.suffix.lower() in [".xlsx", ".xls"]:
        return pd.read_excel(path)
    return pd.read_csv(path)


def objective(x):
    # TODO: 请填写[目标函数]，说明：返回需要最小化的目标值；若要最大化，请返回负目标。
    return (x[0] - 1) ** 2 + (x[1] - 2) ** 2


def run_model(data: pd.DataFrame) -> None:
    constraints = [{"type": "ineq", "fun": lambda x: x[0] + x[1] - 1}]
    res = minimize(objective, x0=np.array(INITIAL_X, dtype=float), bounds=BOUNDS, constraints=constraints, method="SLSQP")
    print(res.message)
    print("最优解:", res.x, "最优值:", res.fun)


if __name__ == "__main__":
    df = load_data()
    run_model(df)
